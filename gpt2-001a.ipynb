# %% [markdown]
# <a href="https://colab.research.google.com/github/qawnaoya/ColabGPT2Example/blob/main/gpt2-001a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.3.3 torch==1.8.0 sentencepiece==0.1.91
# Out:
# ...
#      |████████████████████████████████| 1.9MB 18.2MB/s
# ...
#      |████████████████████████████████| 735.5MB 23kB/s
# ...
#      |████████████████████████████████| 1.1MB 39.4MB/s
# ...
#      |████████████████████████████████| 870kB 51.2MB/s
# ...
#      |████████████████████████████████| 3.3MB 38.8MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=d252a6b6d17500627b5159e52c26fdebde359964b0409bb974780ff8e8ff2fd0
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sacremoses
# ERROR: torchvision 0.9.1+cu101 has requirement torch==1.8.1, but you'll have torch 1.8.0 which is incompatible.
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.8.0 which is incompatible.
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
# ...

# %%
from transformers import T5Tokenizer, AutoModelForCausalLM

# トークナイザーとモデルの準備
tokenizer = T5Tokenizer.from_pretrained("rinna/japanese-gpt2-medium")
model = AutoModelForCausalLM.from_pretrained("rinna/japanese-gpt2-medium")

# 推論
input = tokenizer.encode("昔々あるところに", return_tensors="pt")
output = model.generate(input, do_sample=True, top_p=0.95, top_k=50, num_return_sequences=3)
print(tokenizer.batch_decode(output))
# Out:
# ...
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ['昔々あるところに</s> 女の子が二人 住んでいました。 ある日、おや', '昔々あるところに</s> 小さなお店を 開店準備をしているおばさんが いました', '昔々あるところに</s> 黒猫のウィズ というrpgがありました。 名前は']
